# %%
import os
import requests
import pandas as pd
from dotenv import load_dotenv
import json

# %%
load_dotenv()
api_sportsdata=os.getenv("API_Week_Last_Completed")

# %%
print(api_sportsdata)
# Out:
# 6048ea7610924fd0aa4fb26de0f44b67

# %%
game_week_url = "https://api.sportsdata.io/v3/nfl/scores/json/GameStatsByWeek/2022REG/1"

# %%
Headers = {"Ocp-Apim-Subscription-Key": api_sportsdata}

# %%
response=requests.get(game_week_url, headers = Headers)

# %%
r_json = response.json() # json == format dict, key value pairs

# %%
print(json)
# Out:
# <module 'json' from 'C:\\Users\\bekhr\\anaconda3\\lib\\json\\__init__.py'>

# %%
# response -> dataframe
type(response.json())
# Out:
# list

# %%
df = pd.DataFrame(r_json)

# %%
print(df)
# Out:
#       GameKey                 Date  SeasonType  Season  Week  \
# 0   202210132  2022-09-08T20:20:00           1    2022     1
# 1   202210102  2022-09-11T13:00:00           1    2022     1
# 2   202210105  2022-09-11T13:00:00           1    2022     1
# 3   202210106  2022-09-11T13:00:00           1    2022     1
# 4   202210107  2022-09-11T13:00:00           1    2022     1
# 5   202210111  2022-09-11T13:00:00           1    2022     1
# 6   202210113  2022-09-11T13:00:00           1    2022     1
# 7   202210119  2022-09-11T13:00:00           1    2022     1
# 8   202210124  2022-09-11T13:00:00           1    2022     1
# 9   202210135  2022-09-11T13:00:00           1    2022     1
# 10  202210101  2022-09-11T16:25:00           1    2022     1
# 11  202210129  2022-09-11T16:25:00           1    2022     1
# 12  202210120  2022-09-11T16:25:00           1    2022     1
# 13  202210134  2022-09-11T16:25:00           1    2022     1
# ...

# %%
week_upcoming = "https://api.sportsdata.io/v3/nfl/scores/json/UpcomingWeek?key=6048ea7610924fd0aa4fb26de0f44b67"

# %%
response2=requests.get(week_upcoming, headers = Headers)

# %%
r_json2 = response2.json()

# %%
print(r_json2)
# Out:
# 4

# %%
news = "https://api.sportsdata.io/v3/nfl/scores/json/News?key=6048ea7610924fd0aa4fb26de0f44b67"

# %%
response3=requests.get(news, headers = Headers)

# %%
r_json3 = response3.json()

# %%
print(r_json3)
# Out:
# [{'NewsID': 148285, 'Source': 'RotoBaller', 'Updated': '2022-09-27T04:16:35', 'TimeAgo': '21 hours ago', 'Title': 'Cooper Rush Leads Dallas To Another Victory', 'Content': "Dallas Cowboys quarterback Cooper Rush led the team to another win in a Week 3 game against the division-rival New York Giants. Rush attempted 31 passes, completing 21 of them for 215 yards and one touchdown. Rush zeroed in on wide receiver CeeDee Lamb again, targeting him with 12 of his passes, but once again showing better chemistry with Noah Brown. With Dak Prescott (thumb) stating that he wouldn't rule himself out for Week 4, Rush's reign as the starter may be coming to an end. He's played well enough to keep the Cowboys from rushing Dak back onto the field though. Still, at most it seems like Rush will get one more start before Prescott returns to his space atop the depth chart.", 'Url': 'https://www.rotoballer.com/player-news/cooper-rush-leads-dallas-to-another-victory/1073529', 'TermsOfUse': "RotoBaller Pre
# ...

# %%
pd.DataFrame(r_json3)
# Out:
#    NewsID      Source              Updated       TimeAgo  \
# 0  148285  RotoBaller  2022-09-27T04:16:35  21 hours ago
# 1  148208  RotoBaller  2022-09-26T04:00:20     yesterday
# 2  148081  RotoBaller  2022-09-25T21:49:42    2 days ago
#
#                                          Title  \
# 0  Cooper Rush Leads Dallas To Another Victory
# 1           Tyler Allgeier Quiet In Week 3 Win
# 2       Dalvin Cook Expected To Play In London
#
#                                              Content  \
# 0  Dallas Cowboys quarterback Cooper Rush led the...
# 1  Atlanta Falcons running back Tyler Allgeier ha...
# 2  Minnesota Vikings running back Dalvin Cook (sh...
#
#                                                  Url  \
# 0  https://www.rotoballer.com/player-news/cooper-...
# 1  https://www.rotoballer.com/player-news/tyler-a...
# 2  https://www.rotoballer.com/player-news/dalvin-...
#
#                                           TermsOfUse Author  \
# ...

# %%
player_details = "https://api.sportsdata.io/v3/nfl/scores/json/Players?key=6048ea7610924fd0aa4fb26de0f44b67"

# %%
response3=requests.get(player_details, headers = Headers)

# %%
r_json3 = response3.json()

# %%
print(r_json3)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
player_detals_df = pd.DataFrame(r_json3)

# %%
player_detals_df
# Out:
#       PlayerID  Team  Number FirstName   LastName Position          Status  \
# 0          430  None     NaN       Sam       Koch        P        Inactive
# 1          549   ARI     5.0      Matt     Prater        K          Active
# 2          611   NYJ    19.0       Joe     Flacco       QB          Active
# 3          722  None     NaN     Jason     Witten       TE        Inactive
# 4          732   IND     2.0      Matt       Ryan       QB          Active
# ...        ...   ...     ...       ...        ...      ...             ...
# 4122     24073   DET    15.0   Maurice  Alexander       WR  Practice Squad
# 4123     24075  None     NaN     Corey     Dublin       OL        Inactive
# 4124     24076   ATL    80.0      Josh        Ali       WR  Practice Squad
# 4125     24077  None     NaN    Ferrod    Gardner       DB        Inactive
# 4126     24079  None     NaN     Lucas   Havrisik        K        Inactive
#
# ...

# %%
game_stats = "https://api.sportsdata.io/v3/nfl/scores/json/GameStats/2015REG"

# %%
response4=requests.get(game_stats, headers = Headers)

# %%
r_json4 = response4.json()

# %%
print(r_json4)
# Out:
# {'HttpStatusCode': 401, 'Code': 401, 'Description': 'Unauthorized Season: You are not authorized to pull data for the requested season. To unlock this historical data, please contact sales@sportsdata.io.', 'Help': 'Please contact support@sportsdata.io for assistance'}
